# %% [markdown]
# #1: Exploratory Data Analysis (EDA):
# 1.	Load the dataset and perform basic data exploration.
# 2.	Examine the distribution of features using histograms, box plots, or density plots.
# 3.	Investigate correlations between features to understand relationships within the data.

# %%
import pandas as pd
#Load the Dataset.
df = pd.read_csv('https://raw.githubusercontent.com/Shrikrishna-jadhavar/Data-Science-Material/main/Dataset/wine.csv', index_col = 0)# Load the dataset

df
# Out:
#       Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# Type
# 1       14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       13.20   1.78  2.14        11.2        100     2.65        2.76
# 1       13.16   2.36  2.67        18.6        101     2.80        3.24
# 1       14.37   1.95  2.50        16.8        113     3.85        3.49
# 1       13.24   2.59  2.87        21.0        118     2.80        2.69
# ...       ...    ...   ...         ...        ...      ...         ...
# 3       13.71   5.65  2.45        20.5         95     1.68        0.61
# 3       13.40   3.91  2.48        23.0        102     1.80        0.75
# 3       13.27   4.28  2.26        20.0        120     1.59        0.69
# 3       13.17   2.59  2.37        20.0        120     1.65        0.68
# 3       14.13   4.10  2.74        24.5         96     2.05        0.76
#
#       Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# Type
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 178 entries, 1 to 3
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Alcohol          178 non-null    float64
#  1   Malic            178 non-null    float64
#  2   Ash              178 non-null    float64
#  3   Alcalinity       178 non-null    float64
#  4   Magnesium        178 non-null    int64
#  5   Phenols          178 non-null    float64
#  6   Flavanoids       178 non-null    float64
#  7   Nonflavanoids    178 non-null    float64
#  8   Proanthocyanins  178 non-null    float64
#  9   Color            178 non-null    float64
#  10  Hue              178 non-null    float64
#  11  Dilution         178 non-null    float64
#  12  Proline          178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 19.5 KB

# %%
df.describe()
# Out:
#           Alcohol       Malic         Ash  Alcalinity   Magnesium     Phenols  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean    13.000618    2.336348    2.366517   19.494944   99.741573    2.295112
# std      0.811827    1.117146    0.274344    3.339564   14.282484    0.625851
# min     11.030000    0.740000    1.360000   10.600000   70.000000    0.980000
# 25%     12.362500    1.602500    2.210000   17.200000   88.000000    1.742500
# 50%     13.050000    1.865000    2.360000   19.500000   98.000000    2.355000
# 75%     13.677500    3.082500    2.557500   21.500000  107.000000    2.800000
# max     14.830000    5.800000    3.230000   30.000000  162.000000    3.880000
#
#        Flavanoids  Nonflavanoids  Proanthocyanins       Color         Hue  \
# count  178.000000     178.000000       178.000000  178.000000  178.000000
# mean     2.029270       0.361854         1.590899    5.058090    0.957449
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Set up the plotting environment
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(15, 10))

df.hist(bins=15, figsize=(15, 10), layout=(4, 4))   # Histogram
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %%
plt.figure(figsize=(16, 10))    # Box plots
sns.boxplot(data=df, orient="v", palette="Set2")  #orient v- verical, h- horizontal. Return all unique colors in a categorical Color Brewer palette: sns.color_palette("Set2").
plt.title('Box Plots of Numerical Features')
plt.show()

# %%
# Correlation matrix
correlation_matrix = df.corr()

# Plotting the correlation matrix
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Wine Features')
plt.show()

# %% [markdown]
# # 2: Dimensionality Reduction with PCA:
# 1.	Standardize the features to ensure they have a mean of 0 and a standard deviation of Implement PCA to reduce the dimensionality of the dataset.
# 2.	Determine the optimal number of principal components using techniques like scree plot or cumulative explained variance.
# 3.	Transform the original dataset into the principal components.

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

scaler = StandardScaler() #Standardize the features.
scaled_data = scaler.fit_transform(df.iloc[:, 1:])

pca = PCA() # Implementation PCA and determine the optimal number of principal components.
pca.fit(scaled_data)

explained_variance_ratio = pca.explained_variance_ratio_    # Explained variance ratio for each principal component.
#Explained variance ratio is a measure of the proportion of the total variance in the original dataset that is explained by each principal component.

plt.figure(figsize=(15, 10))
#plt.subplot(1, 2, 1)    # Scree plot
plt.plot(range(1, len(explained_variance_ratio) + 1),explained_variance_ratio, marker = 'o', linestyle = '--', color = 'r') #color = r- red.
plt.title('Scree Plot')
plt.xlabel('Principle Component')
plt.ylabel('Explained Variable Ratio')

#plt.tight_layout()
plt.show()

# %%
cumulative_explained_variance = np.cumsum(explained_variance_ratio)   ## Cumulative explained variance.

plt.figure(figsize = (15,10))
#plt.subplot(1, 2, 2)  # Cumulative explained variance plot.
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--', color='r')
plt.title('Cumulative Explained Variance')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')

#plt.tight_layout()
plt.show()

# %%
n_components_95 = np.argmax(cumulative_explained_variance >= 0.95) + 1    # explain 95% variance number of components.
n_components_95
# Out:
# 9

# %% [markdown]
# # 3: Clustering with Original Data:
# 1.	Apply a clustering algorithm (e.g., K-means) to the original dataset.
# 2.	Visualize the clustering results using appropriate plots.
# 3.	Evaluate the clustering performance using metrics such as silhouette score or Davies–Bouldin index.

# %%
# Apply K-Means Clustering.
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)  # Adjust the number of clusters
kmeans.fit(scaled_data)

labels = kmeans.labels_   # Cluster labels

# %%
# Visualize Clustering.
import matplotlib.pyplot as plt
import seaborn as sns

pca_2d = PCA(n_components=2)  #Visualize the clusters in 2D using the first two principal components or using a scatterplot.
components_2d = pca_2d.fit_transform(scaled_data)

plt.figure(figsize=(15, 8))
sns.scatterplot(x=components_2d[:, 0], y=components_2d[:, 1], hue=labels, palette='Set1')
plt.title('K-Means Clustering Results')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

silhouette_avg = silhouette_score(scaled_data, labels)
davies_bouldin = davies_bouldin_score(scaled_data, labels)

print(f'Silhouette Score :{silhouette_avg}')
print(f'Davis-Bouldin Index : {davies_bouldin}')
# Out:
# Silhouette Score :0.26582340090590717
# Davis-Bouldin Index : 1.4615667034274515

# %% [markdown]
# # 4: Clustering with PCA Data:
# 1.	Apply the same clustering algorithm to the PCA-transformed dataset.
# 2.	Visualize the clustering results obtained from PCA-transformed data.
# 3.	Compare the clustering results from PCA-transformed data with those from the original dataset.

# %%
# Apply K-Means Clustering to PCA-Transformed Dataset.

scaler = StandardScaler() #Standardize the features.
scaled_data = scaler.fit_transform(df.iloc[:, 1:])

pca = PCA()   # Implementation PCA.
pca.fit(scaled_data)

n_components = 2  # number of components based on the explained variance (e.g., 95% variance)
pca = PCA(n_components=n_components)
pca_data = pca.fit_transform(scaled_data)

kmeans_pca = KMeans(n_clusters=3, random_state=42)
kmeans_pca.fit(pca_data)

labels_pca = kmeans_pca.labels_   # Cluster labels for PCA data

# %%
# Visualize Clustering Results from PCA-Transformed Dataset.

plt.figure(figsize=(15, 8))
sns.scatterplot(x=pca_data[:, 0], y=pca_data[:, 1], hue=labels_pca, palette='Set1')
plt.title('K-Means Clustering on PCA-Transformed Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
# Compare the silhouette score and Davies–Bouldin index of the clustering results from the original data and the PCA-transformed data.

silhouette_pca = silhouette_score(pca_data, labels_pca)
davies_bouldin_pca = davies_bouldin_score(pca_data, labels_pca)

print(f'Silhouette Score (Original Data): {silhouette_avg}')
print(f'Silhouette Score (PCA Data): {silhouette_pca}')

print(f'Davies–Bouldin Index (Original Data): {davies_bouldin}')
print(f'Davies–Bouldin Index (PCA Data): {davies_bouldin_pca}')
# Out:
# Silhouette Score (Original Data): 0.26582340090590717
# Silhouette Score (PCA Data): 0.5342171168429738
# Davies–Bouldin Index (Original Data): 1.4615667034274515
# Davies–Bouldin Index (PCA Data): 0.6287723688001484

# %% [markdown]
# # 5: Comparison and Analysis:
# **1.	Compare the clustering results obtained from the original dataset and PCA-transformed data.**
#
# After performing clustering on both the original dataset and the PCA-transformed data, compares the results using metrics such as the silhouette score and Davies–Bouldin index. These metrics help to quantify the quality of the clusters:
#
# **Silhouette Score:** A higher score indicates better separation between clusters. Comparing this score between the original and PCA-transformed data shows how well-defined the clusters are in each case.
#
# **Davies–Bouldin Index:** A lower index value suggests better clustering. This metric helps to determine if the clusters are more compact and well-separated.
#
# Additionally, visual comparisons of cluster assignments can be done by plotting the clusters for both datasets.
#
# **2.	Discuss any similarities or differences observed in the clustering results.**
#
# **Similarities:**
#
# **Cluster Structure:** If both the original and PCA-transformed data maintain similar cluster structures, it suggests that PCA has preserved the essential relationships between features.
# **Cluster Assign:** If many data points are assigned to the same clusters in both cases, PCA has not drastically altered the underlying data structure.
#
# **Differences:**
#
# **Cluster Boundaries:** PCA might alter the cluster boundaries due to the change in feature space, potentially leading to different cluster assignments.
# **Number of Significant Clusters:** In some cases, PCA might reveal a different number of meaningful clusters than the original data, especially if noise is reduced during dimensionality reduction.
#
# **3.	Reflect on the impact of dimensionality reduction on clustering performance.**
#
# **Improved Performance:**
#
# **Noise Reduction:** PCA can reduce noise by focusing on the most significant components, which may lead to more distinct and compact clusters.
# **Computational Efficiency:** With fewer dimensions, clustering algorithms like K-means run faster, especially with large datasets.
#
# **Potential Drawbacks:**
#
# **Loss of Information:** If too many dimensions are reduced, important information might be lost, potentially leading to less meaningful clusters.
# **Interpretability:** Clustering on PCA-transformed data might be harder to interpret because the principal components are linear combinations of the original features.
#
#
# **4.	Analyze the trade-offs between using PCA and clustering directly on the original dataset.**
#
# **When to Use PCA:**
#
# **High-Dimensional Data:** When working with datasets with many features, PCA helps to reduce dimensionality, making clustering more manageable.
# **Correlated Features:** PCA is particularly beneficial when features are highly correlated, as it consolidates information into fewer, uncorrelated principal components.
# **Noise Reduction:** PCA can enhance clustering by eliminating noise and focusing on the most significant patterns in the data.
#
# **When to Avoid PCA:**
#
# **Small Datasets:** In small datasets, the risk of losing crucial information due to dimensionality reduction is higher.
# **Interpretability:** If interpretability of the clusters in terms of the original features is crucial, clustering on the original data may be preferred.

# %% [markdown]
# # 6: Conclusion and Insights
#
# **1.	Summarize the key findings and insights from the assignment.**
#
# **Exploratory Data Analysis:**
#
# The dataset revealed a mix of normally distributed and skewed features, with some significant correlations between features such as Flavanoids and Phenols.
# Correlation analysis highlighted potential multicollinearity, suggesting that dimensionality reduction might be beneficial.
#
# **Dimensionality Reduction with PCA:**
#
# PCA effectively reduced the dataset's dimensionality while retaining most of the variance (e.g., 95% variance explained by a few principal components).
# The PCA transformation resulted in new principal components that were uncorrelated, simplifying the data structure.
#
# **Clustering Analysis:**
#
# Clustering on the original data and PCA-transformed data produced different results in terms of cluster boundaries and performance metrics.
# The clustering on PCA-transformed data generally improved performance metrics (e.g., silhouette score), indicating better-defined clusters due to reduced noise and dimensionality.
#
# **Comparison and Analysis:**
#
# PCA helped to simplify the dataset without losing significant information, leading to more efficient clustering.
# However, the trade-off involved potential loss of interpretability, as the principal components are not as easily understood as the original features.
#
# **2.	Discuss the practical implications of using PCA and clustering in data analysis.**
#
# **PCA:**
#
# **Dimensionality Reduction:** PCA is highly effective in reducing the number of features while retaining most of the data's variance, which is particularly useful in high-dimensional datasets.
# **Noise Reduction:** By focusing on the most significant components, PCA can reduce noise, leading to cleaner and more robust clustering.
# **Improved Computational Efficiency:** PCA can significantly reduce the computational load, especially when working with large datasets.
#
# **Clustering:**
#
# **Data Segmentation:** Clustering is a powerful tool for segmenting data into distinct groups based on similarities, useful in various applications such as customer segmentation, image segmentation, and anomaly detection.
# **Interpretability:** Clustering directly on the original features allows for more straightforward interpretation of the results, as the clusters can be understood in terms of the original features.
#
#
# **3.	Provide recommendations for when to use each technique based on the analysis conducted.**
#
# **When to Use PCA:**
#
# **High-Dimensional Data:** Use PCA when dealing with datasets that have a large number of features to reduce dimensionality and simplify the analysis.
# **Correlated Features:** Apply PCA when features are highly correlated, as it consolidates the information into fewer, uncorrelated principal components.
# **Noise Reduction:** Employ PCA in noisy datasets to focus on the most significant patterns and improve the quality of clustering.
#
# **When to Avoid PCA:**
#
# **Small or Simple Datasets:** Avoid PCA when working with small datasets or when all features are crucial, as PCA may lead to the loss of important information.
# **Need for Interpretability:** If interpretability is key, clustering directly on the original dataset is preferable, as the results are easier to understand in the context of the original features.
