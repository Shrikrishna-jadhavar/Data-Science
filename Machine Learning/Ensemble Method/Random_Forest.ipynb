# %%
# Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, classification_report
import matplotlib.pyplot as plt
from sklearn import tree
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 1000
sns.set_theme(style='darkgrid', palette='rainbow')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Regression

# %%
#Read data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Shrikrishna-jadhavar/April-24/main/Dataset/Boston.csv', index_col=0)
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 1       15.3  396.90   4.98  24.0
# 2       17.8  396.90   9.14  21.6
# ...

# %%
df.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# # Model building

# %%
x = df.iloc[:,:-1]
y = df['medv']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2, random_state=1)

# %%
#Evaluating regressor

# %%
xtest
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 308   0.04932  33.0   2.18     0  0.472  6.849   70.3  3.1827    7  222
# 344   0.02543  55.0   3.78     0  0.484  6.696   56.4  5.7321    5  370
# 48    0.22927   0.0   6.91     0  0.448  6.030   85.5  5.6894    3  233
# 68    0.05789  12.5   6.07     0  0.409  5.878   21.4  6.4980    4  345
# 363   3.67822   0.0  18.10     0  0.770  5.362   96.2  2.1036   24  666
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 93    0.04203  28.0  15.04     0  0.464  6.442   53.6  3.6659    4  270
# 225   0.31533   0.0   6.20     0  0.504  8.266   78.3  2.8944    8  307
# 111   0.10793   0.0   8.56     0  0.520  6.195   54.4  2.7778    5  384
# 427  12.24720   0.0  18.10     0  0.584  5.837   59.7  1.9976   24  666
# 444   9.96654   0.0  18.10     0  0.740  6.485  100.0  1.9784   24  666
#
#      ptratio   black  lstat
# 308     18.4  396.90   7.53
# 344     17.6  396.90   7.18
# ...

# %%
len(xtrain)
# Out:
# 404

# %%
rf = RandomForestRegressor()
rf.fit(xtrain,ytrain)
ypred = rf.predict(xtest)
ypred
# Out:
# array([30.214, 27.29 , 19.872, 20.455, 20.024, 19.573, 27.735, 19.31 ,
#        20.145, 23.197, 28.422, 30.861, 20.428, 19.945, 20.428, 25.856,
#        12.107, 41.593, 23.904, 14.163, 20.065, 16.797, 24.842, 23.826,
#        25.146,  9.251, 14.699, 19.794, 43.297, 12.388, 26.048, 20.116,
#        47.256, 16.293, 23.266, 20.913, 15.295, 33.269, 12.828, 20.056,
#        24.148, 23.067, 25.861, 16.339, 15.895, 12.119, 46.721, 11.522,
#        22.027, 18.473, 23.189, 21.862, 25.096, 20.856, 10.629, 23.627,
#        11.922, 23.615, 18.755, 43.263, 14.35 , 26.415, 13.341, 14.771,
#        17.962, 32.979, 42.158, 24.629, 21.791, 20.434, 24.073,  6.862,
#        18.599, 21.204, 19.448, 20.758, 43.243, 24.152, 27.583, 32.55 ,
#        17.562, 20.785, 33.777, 11.761, 24.38 , 25.509, 14.817, 24.964,
#        19.944, 17.928, 28.328, 46.373, 16.208, 21.716, 15.314, 20.992,
#        24.345, 23.647, 42.815, 20.553, 15.612, 15.866])

# %%
r2_score(ytest,ypred)
# Out:
# 0.9140073988570474

# %%
print('R2 value :', r2_score(ytest, ypred))
# Out:
# R2 value : 0.9140073988570474

# %%
mean_squared_error(ytest,ypred)
# Out:
# 8.498424284313733

# %%
np.sqrt(mean_squared_error(ytest, ypred))
# Out:
# 2.9152057018868724

# %%
print(f"R2 values: {r2_score(ytest, ypred)}")
print(f"MSE: {mean_squared_error(ytest,ypred)}")
print(f"RMSE: {np.sqrt(mean_squared_error(ytest,ypred))}")
# Out:
# R2 values: 0.9140073988570474
# MSE: 8.498424284313733
# RMSE: 2.9152057018868724

# %%
#Visualize the rf

# %%
rf.estimators_
# Out:
# [DecisionTreeRegressor(max_features=1.0, random_state=1358421835),
#  DecisionTreeRegressor(max_features=1.0, random_state=1743905932),
#  DecisionTreeRegressor(max_features=1.0, random_state=556179018),
#  DecisionTreeRegressor(max_features=1.0, random_state=1339257570),
#  DecisionTreeRegressor(max_features=1.0, random_state=1958874712),
#  DecisionTreeRegressor(max_features=1.0, random_state=1520930396),
#  DecisionTreeRegressor(max_features=1.0, random_state=1626122146),
#  DecisionTreeRegressor(max_features=1.0, random_state=1300537169),
#  DecisionTreeRegressor(max_features=1.0, random_state=129231896),
#  DecisionTreeRegressor(max_features=1.0, random_state=1675232312),
#  DecisionTreeRegressor(max_features=1.0, random_state=1981037326),
#  DecisionTreeRegressor(max_features=1.0, random_state=93624570),
#  DecisionTreeRegressor(max_features=1.0, random_state=1162500742),
#  DecisionTreeRegressor(max_features=1.0, random_state=226420747),
# ...

# %%
len(rf.estimators_)
# Out:
# 100

# %%
rf.estimators_[99]
# Out:
# DecisionTreeRegressor(max_features=1.0, random_state=939488383)

# %%
x.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat'],
#       dtype='object')

# %%
tree.plot_tree(rf.estimators_[85], feature_names=x.columns,
               filled=True, max_depth=3)
plt.show()

# %% [markdown]
# # Classification

# %%
#Read the dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Shrikrishna-jadhavar/April-24/main/Dataset/Mobile_price_range.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
sns.countplot(x = df['price_range'])
# Out:
# <Axes: xlabel='price_range', ylabel='count'>

# %%
df['price_range'].replace([0,1,2,3],['low','medium', 'high','very high'], inplace=True)

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#Evaluate model

# %%
x = df.iloc[:,:-1]
y = df['price_range']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.2, random_state = 1)

# %%
rfc = RandomForestClassifier()
rfc.fit(xtrain,ytrain)
yp = rfc.predict(xtest)

# %%
xtest
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 674            1034     0          2.6         1   2       1          45
# 1699           1002     1          1.8         0   1       0          45
# 1282            609     1          0.5         0   4       1          10
# 1315           1510     0          0.6         1   1       0          32
# 1210            805     1          1.7         1   0       1          58
# ...             ...   ...          ...       ...  ..     ...         ...
# 400            1266     0          1.9         1   0       1           7
# 763            1741     1          1.8         0   0       0          14
# 385            1880     1          1.8         0   4       1          18
# 1667           1967     0          0.5         0   0       1          46
# 1820            665     1          0.7         0   0       1          31
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
yp
# Out:
# array(['low', 'low', 'medium', 'low', 'high', 'medium', 'low', 'high',
#        'high', 'very high', 'low', 'very high', 'medium', 'medium',
#        'high', 'low', 'low', 'medium', 'medium', 'high', 'very high',
#        'very high', 'medium', 'high', 'very high', 'high', 'high',
#        'very high', 'high', 'high', 'high', 'medium', 'high', 'low',
#        'very high', 'very high', 'low', 'low', 'medium', 'low', 'medium',
#        'low', 'high', 'medium', 'low', 'medium', 'high', 'high', 'medium',
#        'high', 'high', 'very high', 'medium', 'very high', 'high',
#        'very high', 'medium', 'high', 'very high', 'medium', 'low',
#        'high', 'medium', 'very high', 'high', 'medium', 'low', 'high',
#        'very high', 'high', 'medium', 'high', 'low', 'very high',
#        'very high', 'medium', 'high', 'medium', 'low', 'low', 'low',
#        'very high', 'medium', 'high', 'very high', 'high', 'high', 'low',
# ...

# %%
print(classification_report(ytest,yp))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.81      0.83      0.82       106
#          low       0.91      0.93      0.92        92
#       medium       0.81      0.84      0.83        96
#    very high       0.95      0.87      0.91       106
#
#     accuracy                           0.87       400
#    macro avg       0.87      0.87      0.87       400
# weighted avg       0.87      0.87      0.87       400

# %%
#Try to visualize first 5 decision trees.

# %%
len(rfc.estimators_)
# Out:
# 100

# %%
tree.plot_tree(rfc.estimators_[0], feature_names = x.columns,
               class_names = df ['price_range'].unique(),
               filled = True , max_depth = 3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
