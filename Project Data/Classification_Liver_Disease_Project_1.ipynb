# %% [markdown]
# # 1. Loading the Data
#
# First, import the necessary libraries and load the dataset into a DataFrame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/Shrikrishna-jadhavar/Data-Science-Material/refs/heads/main/Dataset/Liver-Disease%20Project%20dataset.csv')

df
# Out:
#         category  age sex  albumin  alkaline_phosphatase  \
# 0     no_disease   32   m     38.5                  52.5
# 1     no_disease   32   m     38.5                  70.3
# 2     no_disease   32   m     46.9                  74.7
# 3     no_disease   32   m     43.2                  52.0
# 4     no_disease   32   m     39.2                  74.1
# ..           ...  ...  ..      ...                   ...
# 610    cirrhosis   62   f     32.0                 416.6
# 611    cirrhosis   64   f     24.0                 102.8
# 612    cirrhosis   64   f     29.0                  87.3
# 613    cirrhosis   46   f     33.0                   NaN
# 614    cirrhosis   59   f     36.0                   NaN
#
#      alanine_aminotransferase  aspartate_aminotransferase  bilirubin  \
# 0                         7.7                        22.1        7.5
# 1                        18.0                        24.7        3.9
# 2                        36.2                        52.6        6.1
# 3                        30.6                        22.6       18.9
# 4                        32.6                        24.8        9.6
# ..                        ...                         ...        ...
# 610                       5.9                       110.3       50.0
# 611                       2.9                        44.4       20.0
# 612                       3.5                        99.0       48.0
# 613                      39.0                        62.0       20.0
# 614                     100.0                        80.0       12.0
#
#      cholinesterase  cholesterol  creatinina  gamma_glutamyl_transferase   \
# 0              6.93         3.23       106.0                         12.1
# 1             11.17         4.80        74.0                         15.6
# 2              8.84         5.20        86.0                         33.2
# 3              7.33         4.74        80.0                         33.8
# 4              9.15         4.32        76.0                         29.9
# ..              ...          ...         ...                          ...
# 610            5.57         6.30        55.7                        650.9
# 611            1.54         3.02        63.0                         35.9
# 612            1.66         3.63        66.7                         64.2
# 613            3.56         4.20        52.0                         50.0
# 614            9.07         5.30        67.0                         34.0
#
#     protein
# 0           69
# 1         76.5
# 2         79.3
# 3         75.7
# 4         68.7
# ..         ...
# 610       68.5
# 611       71.3
# 612         82
# 613         71
# 614         68
#
# [615 rows x 13 columns]

# %% [markdown]
# #2.Understanding the Data Structure
#
# *Shape of the Data*

# %%
print(f'The dataset contains {df.shape[0]} rows and {df.shape[1]} columns.')

#or

#df.shape
# Out:
# The dataset contains 615 rows and 13 columns.

# %% [markdown]
# *First Few Rows*

# %%
df.head()
# Out:
#       category  age sex  albumin  alkaline_phosphatase  \
# 0   no_disease   32   m     38.5                  52.5
# 1   no_disease   32   m     38.5                  70.3
# 2   no_disease   32   m     46.9                  74.7
# 3   no_disease   32   m     43.2                  52.0
# 4   no_disease   32   m     39.2                  74.1
#
#    alanine_aminotransferase  aspartate_aminotransferase  bilirubin  \
# 0                       7.7                        22.1        7.5
# 1                      18.0                        24.7        3.9
# 2                      36.2                        52.6        6.1
# 3                      30.6                        22.6       18.9
# 4                      32.6                        24.8        9.6
#
#    cholinesterase  cholesterol  creatinina  gamma_glutamyl_transferase   \
# 0            6.93         3.23       106.0                         12.1
# 1           11.17         4.80        74.0                         15.6
# 2            8.84         5.20        86.0                         33.2
# 3            7.33         4.74        80.0                         33.8
# 4            9.15         4.32        76.0                         29.9
#
#   protein
# 0         69
# 1       76.5
# 2       79.3
# 3       75.7
# 4       68.7

# %% [markdown]
# *Data Types and Non-Null Counts*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   category                     615 non-null    object
#  1   age                          615 non-null    int64
#  2   sex                          615 non-null    object
#  3   albumin                      614 non-null    float64
#  4   alkaline_phosphatase         597 non-null    float64
#  5   alanine_aminotransferase     614 non-null    float64
#  6   aspartate_aminotransferase   615 non-null    float64
#  7   bilirubin                    615 non-null    float64
#  8   cholinesterase               615 non-null    float64
#  9   cholesterol                  605 non-null    float64
#  10  creatinina                   615 non-null    float64
#  11  gamma_glutamyl_transferase   615 non-null    float64
#  12  protein                      615 non-null    object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 62.6+ KB

# %% [markdown]
# **Statistical Summary**
#
# *Descriptive Statistics for Numerical Columns*

# %%
df.describe()
# Out:
#               age     albumin  alkaline_phosphatase  alanine_aminotransferase  \
# count  615.000000  614.000000            597.000000                614.000000
# mean    47.408130   41.620195             68.283920                 28.450814
# std     10.055105    5.780629             26.028315                 25.469689
# min     19.000000   14.900000             11.300000                  0.900000
# 25%     39.000000   38.800000             52.500000                 16.400000
# 50%     47.000000   41.950000             66.200000                 23.000000
# 75%     54.000000   45.200000             80.100000                 33.075000
# max     77.000000   82.200000            416.600000                325.300000
#
#        aspartate_aminotransferase   bilirubin  cholinesterase  cholesterol  \
# count                  615.000000  615.000000      615.000000   605.000000
# mean                    34.786341   11.396748        8.196634     5.368099
# std                     33.090690   19.673150        2.205657     1.132728
# min                     10.600000    0.800000        1.420000     1.430000
# 25%                     21.600000    5.300000        6.935000     4.610000
# 50%                     25.900000    7.300000        8.260000     5.300000
# 75%                     32.900000   11.200000        9.590000     6.060000
# max                    324.000000  254.000000       16.410000     9.670000
#
#         creatinina  gamma_glutamyl_transferase
# count   615.000000                   615.000000
# mean     81.287805                    39.533171
# std      49.756166                    54.661071
# min       8.000000                     4.500000
# 25%      67.000000                    15.700000
# 50%      77.000000                    23.300000
# 75%      88.000000                    40.200000
# max    1079.100000                   650.900000

# %% [markdown]
# *Descriptive Statistics for Categorical Columns*

# %%
#df.describe(include='object')    # Or

df.describe(include=['object'])
# Out:
#            category  sex protein
# count           615  615        615
# unique            5    2        199
# top      no_disease    m       71.9
# freq            533  377         15

# %% [markdown]
# #3.Handling Missing Values
#
# *Counting Missing Values per Column*

# %%
df.isnull().sum()
# Out:
# category                        0
# age                             0
# sex                             0
# albumin                         1
# alkaline_phosphatase           18
# alanine_aminotransferase        1
# aspartate_aminotransferase      0
# bilirubin                       0
# cholinesterase                  0
# cholesterol                    10
# creatinina                      0
# gamma_glutamyl_transferase      0
# protein                         0
# dtype: int64

# %% [markdown]
# *Drop Missing Values*

# %%
df.dropna(inplace=True)

# %% [markdown]
# **Impute Missing Values**
#
# *For Numerical Columns*

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
df['albumin'] = imputer.fit_transform(df[['albumin']])

# %% [markdown]
# *For Categorical Columns*

# %%
df['category'].fillna(df['category'].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 589 entries, 0 to 612
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   category                     589 non-null    object
#  1   age                          589 non-null    int64
#  2   sex                          589 non-null    object
#  3   albumin                      589 non-null    float64
#  4   alkaline_phosphatase         589 non-null    float64
#  5   alanine_aminotransferase     589 non-null    float64
#  6   aspartate_aminotransferase   589 non-null    float64
#  7   bilirubin                    589 non-null    float64
#  8   cholinesterase               589 non-null    float64
#  9   cholesterol                  589 non-null    float64
#  10  creatinina                   589 non-null    float64
#  11  gamma_glutamyl_transferase   589 non-null    float64
#  12  protein                      589 non-null    object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 64.4+ KB

# %%
df.isnull().sum()
# Out:
# category                       0
# age                            0
# sex                            0
# albumin                        0
# alkaline_phosphatase           0
# alanine_aminotransferase       0
# aspartate_aminotransferase     0
# bilirubin                      0
# cholinesterase                 0
# cholesterol                    0
# creatinina                     0
# gamma_glutamyl_transferase     0
# protein                        0
# dtype: int64

# %% [markdown]
# #4.Data Cleaning
#
# *Standardizing Column Names*
#
# *Renaming Columns*

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# **Correcting Data Types**
#
# *Converting 'sex' to Categorical*

# %%
df['sex'] = df['sex'].astype('category')

# %% [markdown]
# **Encoding Categorical Variables**
#
# *Label Encoding*

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['category_encoded'] = le.fit_transform(df['category'])

# %% [markdown]
# *One-Hot Encoding*

# %%
df = pd.get_dummies(df, columns=['sex'], drop_first=True)

# %%
df.head()
# Out:
#       category  age  albumin  alkaline_phosphatase  alanine_aminotransferase  \
# 0   no_disease   32     38.5                  52.5                       7.7
# 1   no_disease   32     38.5                  70.3                      18.0
# 2   no_disease   32     46.9                  74.7                      36.2
# 3   no_disease   32     43.2                  52.0                      30.6
# 4   no_disease   32     39.2                  74.1                      32.6
#
#    aspartate_aminotransferase  bilirubin  cholinesterase  cholesterol  \
# 0                        22.1        7.5            6.93         3.23
# 1                        24.7        3.9           11.17         4.80
# 2                        52.6        6.1            8.84         5.20
# 3                        22.6       18.9            7.33         4.74
# 4                        24.8        9.6            9.15         4.32
#
#    creatinina  gamma_glutamyl_transferase_ protein___  category_encoded  sex_m
# 0       106.0                         12.1         69                 3   True
# 1        74.0                         15.6       76.5                 3   True
# 2        86.0                         33.2       79.3                 3   True
# 3        80.0                         33.8       75.7                 3   True
# 4        76.0                         29.9       68.7                 3   True

# %% [markdown]
# #5.Exploratory Visualizations
#
# **1. Univariate Analysis**
#
# *Histogram*

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[numerical_cols].hist(figsize=(15, 10))
plt.show()

# %% [markdown]
# *Box Plots*

# %%
for col in numerical_cols:
    sns.boxplot(x=df[col])
    plt.show()

# %% [markdown]
# **2. Bivariate Analysis**

# %% [markdown]
# *Scatter Plots*

# %%
# Check if 'category' column still exists before plotting the scatterplot
if 'category' in df.columns:
    # Now you can plot the scatterplot
    sns.scatterplot(data=df, x='age', y='bilirubin', hue='category')
    plt.show()
else:
    print("Warning: 'category' column was dropped and cannot be used for hue.")

# %% [markdown]
# **3.Multivariate Analysis**
#
# *Pair Plot*

# %%
sns.pairplot(df, hue='category')
plt.show()

# %% [markdown]
# # 7.Insights from the Data

# %% [markdown]
# **Age Distribution: Determine if liver disease prevalence varies with age.**

# %% [markdown]
# *Violin Plot*

# %%
sns.violinplot(x='category', y='age', data=df)
plt.show()

# %% [markdown]
# **Gender Distribution: Analyze the distribution of liver disease across genders.**

# %% [markdown]
# *Count Plot*

# %%
# Print the column names of your DataFrame to check the actual name of the 'sex' column.
print(df.columns)
# Out:
# Index(['category', 'age', 'albumin', 'alkaline_phosphatase',
#        'alanine_aminotransferase', 'aspartate_aminotransferase', 'bilirubin',
#        'cholinesterase', 'cholesterol', 'creatinina',
#        'gamma_glutamyl_transferase_', 'protein___', 'category_encoded',
#        'sex_m'],
#       dtype='object')

# %%
sns.countplot(x='sex_m', hue='category', data=df)
plt.show()

# %% [markdown]
# **Enzyme Levels: Investigate if certain enzyme levels are higher in individuals with liver disease.**

# %% [markdown]
# *Box Plot*

# %%
sns.boxplot(x='category', y='alanine_aminotransferase', data=df)
plt.show()

# %% [markdown]
# *Correlation Heatmap*

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert columns with 'object' dtype to numerical if possible, excluding 'category'.
# Columns with non-numerical data that can't be converted will be dropped.
for col in df.select_dtypes(include=['object']).columns:
    if col == 'category':  # Skip the 'category' column
        continue
    try:
        # Attempt to convert the column to numeric, handling errors
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Use errors='coerce' to handle invalid values
    except ValueError:
        print(f"Warning: Column '{col}' contains non-numerical data and will be excluded from correlation.")
        df = df.drop(columns=[col])  # Drop the problematic column

# Before calculating correlation, drop non-numeric columns or convert them to numeric
# Drop the category column since it's non-numeric and causes issues with correlation
df_numeric = df.drop(columns=['category'])

# Alternatively, If you want to include 'category' in correlation, convert it to numerical using one-hot encoding:
# df_numeric = pd.get_dummies(df, columns=['category'], drop_first=True)

# Calculate and plot the correlation matrix using only numeric data.
plt.figure(figsize=(12, 8))
sns.heatmap(df_numeric.corr(), annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# #6.Statistical Analysis
# **1.Correlation Analysis**
#
# *Identifying Strong Correlations*

# %%
# Before calculating correlation, select only numeric columns
numeric_cols = df.select_dtypes(include=['number']).columns  # Select only numeric columns
df_numeric = df[numeric_cols]  # Create a DataFrame with only numeric columns

# Calculate and plot the correlation matrix using only numeric data.
corr_matrix = df_numeric.corr()  # Calculate correlation for numeric columns only
strong_corrs = corr_matrix[abs(corr_matrix) > 0.5]

# %% [markdown]
# **2.Outlier Detection**
#
# *Using Z-Score*

# %%
from scipy import stats
import numpy as np

# Assuming 'numerical_cols' is a list of your numerical columns
# Calculate z-scores for each numerical column separately and store in new columns

for col in numerical_cols:
    df[col + '_zscore'] = np.abs(stats.zscore(df[col]))  # Calculate and assign to a new column

# If you need a single 'z_score' column indicating any outlier:
df['z_score'] = df[[col + '_zscore' for col in numerical_cols]].max(axis=1)  # Max z-score across all columns

df_outliers = df[df['z_score'] > 3]  # Now you can filter outliers based on this column

# %% [markdown]
# *Using IQR Method*

# %%
Q1 = df[numerical_cols].quantile(0.25)
Q3 = df[numerical_cols].quantile(0.75)
IQR = Q3 - Q1

# Filter outliers only for numerical columns, then use the index to filter the original DataFrame
df_outliers = df[((df[numerical_cols] < (Q1 - 1.5 * IQR)) | (df[numerical_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df_outliers
# Out:
#         category  age  albumin  alkaline_phosphatase  \
# 2     no_disease   32     46.9                  74.7
# 5     no_disease   32     41.6                  43.3
# 9     no_disease   32     42.4                  86.3
# 18    no_disease   33     36.6                  57.1
# 22    no_disease   34     42.7                  65.3
# ..           ...  ...      ...                   ...
# 608    cirrhosis   58     34.0                  46.4
# 609    cirrhosis   59     39.0                  51.3
# 610    cirrhosis   62     32.0                 416.6
# 611    cirrhosis   64     24.0                 102.8
# 612    cirrhosis   64     29.0                  87.3
#
#      alanine_aminotransferase  aspartate_aminotransferase  bilirubin  \
# 2                        36.2                        52.6        6.1
# 5                        18.5                        19.7       12.3
# 9                        20.3                        20.0       35.2
# 18                       38.9                        40.3       24.9
# 22                       46.7                        30.3       23.4
# ..                        ...                         ...        ...
# 608                      15.0                       150.0        8.0
# 609                      19.6                       285.8       40.0
# 610                       5.9                       110.3       50.0
# 611                       2.9                        44.4       20.0
# 612                       3.5                        99.0       48.0
#
#      cholinesterase  cholesterol  creatinina  ...  \
# 2              8.84         5.20        86.0  ...
# 5              9.92         6.05       111.0  ...
# 9              5.46         4.45        81.0  ...
# 18             9.62         5.50       112.0  ...
# 22            10.95         5.06        75.0  ...
# ..              ...          ...         ...  ...
# 608            6.26         3.98        56.0  ...
# 609            5.77         4.51       136.1  ...
# 610            5.57         6.30        55.7  ...
# 611            1.54         3.02        63.0  ...
# 612            1.66         3.63        66.7  ...
#
#      alkaline_phosphatase_zscore  alanine_aminotransferase_zscore  \
# 2                       0.253944                         0.461714
# 5                       0.958455                         0.387394
# 9                       0.701837                         0.301044
# 18                      0.425617                         0.591239
# 22                      0.109004                         0.965422
# ..                           ...                              ...
# 608                     0.838760                         0.555297
# 609                     0.649564                         0.334624
# 610                    13.455196                         0.991844
# 611                     1.338926                         1.135760
# 612                     0.740448                         1.106977
#
#      aspartate_aminotransferase_zscore  bilirubin_zscore  \
# 2                             0.573318          0.282787
# 5                             0.428541          0.073703
# 9                             0.419405          1.390417
# 18                            0.198763          0.798183
# 22                            0.105754          0.711936
# ..                                 ...               ...
# 608                           3.539307          0.173540
# 609                           7.674639          1.666409
# 610                           2.330377          2.241393
# 611                           0.323615          0.516441
# 612                           1.986274          2.126396
#
#      cholinesterase_zscore  cholesterol_zscore  creatinina_zscore  \
# 2                 0.290683            0.169629           0.085500
# 5                 0.784011            0.583920           0.579045
# 9                 1.253252            0.834526           0.013209
# 18                0.646976            0.096329           0.598787
# 22                1.254500            0.293743           0.131660
# ..                     ...                 ...                ...
# 608               0.887823            1.251194           0.506754
# 609               1.111648            0.781334           1.074564
# 610               1.203005            0.805552           0.512677
# 611               3.043850            2.102261           0.368562
# 612               2.989036            1.561479           0.295517
#
#      gamma_glutamyl_transferase__zscore  category_encoded_zscore    z_score
# 2                              0.092127                 0.272911   1.553745
# 5                              0.973187                 0.272911   1.553745
# 9                              0.410984                 0.272911   1.553745
# 18                             0.195341                 0.272911   1.452968
# 22                             1.131694                 0.272911   1.352191
# ..                                  ...                      ...        ...
# 608                            0.211985                 4.151258   4.151258
# 609                            1.159341                 4.151258   7.674639
# 610                           11.292728                 4.151258  13.455196
# 611                            0.042363                 4.151258   4.151258
# 612                            0.479235                 4.151258   4.151258
#
# [166 rows x 26 columns]
