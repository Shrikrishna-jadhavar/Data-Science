# %% [markdown]
# # **Matplotlib Markers**

# %% [markdown]
# Markers
#
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %%
# Mark each point with a circle:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
# Mark each point with a star:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
# Mark each point with a point:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '.')
plt.show()

# %%
# Mark each point with a pixel:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = ',')
plt.show()

# %%
# Mark each point with a x:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'x')
plt.show()

# %%
# Mark each point with a X(filled):

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'X')
plt.show()

# %%
# Mark each point with a plus:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '+')
plt.show()

# %%
# Mark each point with a plus filled:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'P')
plt.show()

# %%
# Mark each point with a square:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 's')
plt.show()

# %%
# Mark each point with a Diamond:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'D')
plt.show()

# %%
# Mark each point with a diamond thin:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'd')
plt.show()

# %%
# Mark each point with a pentagon:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'p')
plt.show()

# %%
# Mark each point with a Hexagon:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'H')
plt.show()

# %%
# Mark each point with a hexagon:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'h')
plt.show()

# %%
# Mark each point with a triangle down:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'v')
plt.show()

# %%
# Mark each point with a triangle up:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '^')
plt.show()

# %%
# Mark each point with a Triangle left:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '<')
plt.show()

# %%
# Mark each point with a Triangle right:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '>')
plt.show()

# %%
# Mark each point with a Tri down:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '1')
plt.show()

# %%
# Mark each point with a Tri up:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '2')
plt.show()

# %%
# Mark each point with a Tri left:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '3')
plt.show()

# %%
# Mark each point with a Tri right:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '4')
plt.show()

# %%
# Mark each point with a VLine:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '|')
plt.show()

# %%
# Mark each point with a HLine:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '_')
plt.show()

# %% [markdown]
# # **Format Strings fmt**
#
# You can also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker | line | color

# %%
# Mark each point with a circle:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# The marker value can be anything from the Marker Reference above.
#
# The line value can be one of the following:

# %% [markdown]
# # **Line Reference**

# %%
# Mark each point with a solid line:

ypoints = np.array([3, 8, 1, 10])

#plt.plot(ypoints, linestyle = 'solid')
plt.plot(ypoints, '-')
plt.show()

# %%
# Mark each point with a Dotted line:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
#plt.plot(ypoints, ':')
plt.show()

# %%
# Mark each point with a dashed line:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dashed')
#plt.plot(ypoints, '--')
plt.show()

# %%
# Mark each point with a dashed/dotted line:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dashdot')
#plt.plot(ypoints, '-.')
plt.show()

# %%
# Mark each point with a dashed/dotted line:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = '')
#plt.plot(ypoints, '')
plt.show()

# %% [markdown]
# The short color value can be one of the following:

# %% [markdown]
# # **Color Reference**

# %%
# mark each point with a red lines and dots.

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'or')
plt.show()

# %%
# mark each point with a Green dots.

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'og')
plt.show()

# %%
# mark each point with a Blue dots.

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'ob')
plt.show()

# %%
# mark each point with a Cyan dots.

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'oc')
plt.show()

# %%
# mark each point with a magenta dots.

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'om')
plt.show()

# %%
# mark each point with a Yellow dots.

ypoints = np.array([3, 5, 7, 9])

plt.plot(ypoints, 'oy')
plt.show()

# %%
# mark each point with a Black dots.

ypoints = np.array([3, 5, 7, 9])

plt.plot(ypoints, 'ok')
plt.show()

# %%
# mark each point with a White dots.

ypoints = np.array([3, 5, 7, 9])

plt.plot(ypoints, 'ow')
plt.show()

# %% [markdown]
# # **Marker Size**
#
# You can use the keyword argument markersize or the shorter version, ms to set the size of the markers:

# %%
# Set the size of the markers to 20:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# # **Marker Color**
#
# You can use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers:

# %%
# Set the EDGE color to red:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o',ms = '20', mec = 'r')
plt.show()

# %% [markdown]
# You can use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers:

# %%
# Set the FACE color to red:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o',ms = '20', mfc = 'r')
plt.show()

# %% [markdown]
# Use both the mec and mfc arguments to color the entire marker:

# %%
# Set the color of both the edge and the face to red:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o',ms = '20', mec = 'r', mfc = 'r')
plt.show()

# %% [markdown]
# You can also use Hexadecimal color values:

# %%
# Mark each point with a beautiful green color:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %%
# Mark each point with the color named "hotpink":

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()
